# %% [markdown]
# <!-- ===== Gradient Header ===== -->
# <p style="background: linear-gradient(90deg, #1a237e, #1565c0, #0288d1, #26c6da);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 26px;
#          text-align: center;
#          color: #ffffff;
#          padding: 24px 42px;
#          border-radius: 30px;
#          border: 3px solid #0288d1;
#          box-shadow: 0 10px 25px rgba(2,136,209,0.35);
#          letter-spacing: 1.2px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 2px 2px 4px rgba(0,0,0,0.25);
#          margin: 10px 0 20px;">
#   📊 Complete EDA — Heart Disease Dataset Analysis
# </p>
#
# <!-- ===== Meta Badges ===== -->
# <div style="display:flex; gap:12px; flex-wrap:wrap; font-family:'Montserrat',sans-serif; margin: 0 2px 18px;">
#   <span style="background:#fff0f0; border:1px solid #ffb3b3; color:#8b0000;
#                padding:8px 16px; border-radius:999px; font-size:13px; box-shadow:0 3px 10px rgba(0,0,0,0.06); font-weight:600;">
#     👤 <b>Author:</b> Asadullah Shehbaz
#   </span>
#   <span style="background:#f0f8ff; border:1px solid #b8d8ff; color:#1a4d8b;
#                padding:8px 16px; border-radius:999px; font-size:13px; box-shadow:0 3px 10px rgba(0,0,0,0.06); font-weight:600;">
#     🔍 <b>Project Type:</b> Exploratory Data Analysis (EDA)
#   </span>
#   <span style="background:#fff9f0; border:1px solid #ffd9a8; color:#8b5a00;
#                padding:8px 16px; border-radius:999px; font-size:13px; box-shadow:0 3px 10px rgba(0,0,0,0.06); font-weight:600;">
#     🏥 <b>Domain:</b> Medical / Healthcare
#   </span>
#   <span style="background:#f5f0ff; border:1px solid #d4b8ff; color:#4a0080;
#                padding:8px 16px; border-radius:999px; font-size:13px; box-shadow:0 3px 10px rgba(0,0,0,0.06); font-weight:600;">
#     🎯 <b>Task:</b> Binary Classification (Pre-Modeling)
#   </span>
#   <span style="background:#f0fff4; border:1px solid #9effc0; color:#005a1f;
#                padding:8px 16px; border-radius:999px; font-size:13px; box-shadow:0 3px 10px rgba(0,0,0,0.06); font-weight:600;">
#     📦 <b>Dataset:</b> 630,000 rows × 15 columns
#   </span>
# </div>
#
# <!-- ===== Objective Card ===== -->
# <p style="font-family: 'Montserrat', sans-serif;
#           font-size: 16px;
#           line-height: 1.8;
#           color: #2c2c2c;
#           background: linear-gradient(135deg, #ffe5e5 0%, #fff5f5 100%);
#           padding: 18px 22px;
#           border-radius: 16px;
#           border-left: 6px solid #e53e3e;
#           box-shadow: 0 5px 18px rgba(231,76,60,0.12);
#           margin: 0 0 20px;">
#   🎯 <b style="font-size:17px;">Objective:</b> Conduct a comprehensive exploratory data analysis on a 630,000-patient heart disease dataset to uncover clinical patterns, risk factors, and feature relationships. This analysis covers data quality checks, statistical summaries, outlier detection, univariate and bivariate analysis, correlation studies, and statistical significance testing — all designed to build a solid foundation before training any Machine Learning model.
# </p>
#
# <!-- ===== Dataset Info Card ===== -->
# <div style="font-family:'Montserrat',sans-serif;
#             background:linear-gradient(135deg, #fef3e2 0%, #fff9f0 100%);
#             padding:20px 22px;
#             border-radius:16px;
#             border:2px solid #ffd699;
#             box-shadow:0 6px 20px rgba(255,165,0,0.1);
#             color:#2a2a2a;
#             margin-bottom:20px;">
#   <div style="display:flex; align-items:center; gap:10px; margin-bottom:10px;">
#     <span style="font-size:22px;">📂</span>
#     <h3 style="margin:0; font-size:18px; color:#cc7a00; font-weight:700;">Dataset Information</h3>
#   </div>
#   <ul style="margin:10px 0 0 20px; padding:0; line-height:1.9; font-size:15px;">
#     <li>🏥 <b>Domain:</b> Cardiology / Clinical Medicine</li>
#     <li>👥 <b>Patients:</b> 630,000 records — large-scale real-world medical data</li>
#     <li>📋 <b>Features:</b> 14 clinical variables (demographics, vitals, lab tests, imaging)</li>
#     <li>🎯 <b>Target:</b> <code>Heart Disease</code> — Presence (44.8%) vs Absence (55.2%)</li>
#     <li>✅ <b>Data Quality:</b> Zero missing values, zero duplicates — clean and ready</li>
#     <li>📊 <b>Analysis Depth:</b> 9-step comprehensive EDA pipeline</li>
#   </ul>
# </div>
#
# <!-- ===== Pipeline Card ===== -->
# <div style="font-family:'Montserrat',sans-serif;
#             background:#ffffff;
#             padding:20px 22px;
#             border-radius:16px;
#             border:2px solid #e8e8e8;
#             box-shadow:0 8px 24px rgba(0,0,0,0.08);
#             color:#2a2a2a;
#             margin-bottom:20px;">
#   <div style="display:flex; align-items:center; gap:10px; margin-bottom:12px;">
#     <span style="font-size:22px;">🔧</span>
#     <h3 style="margin:0; font-size:18px; color:#2c2c2c; font-weight:700;">EDA Pipeline (9 Steps)</h3>
#   </div>
#   <ul style="margin:10px 0 0 20px; padding:0; line-height:2; font-size:15px;">
#     <li>📚 <b>1. Import Libraries</b> — Pandas, NumPy, Matplotlib, Seaborn, Plotly, SciPy</li>
#     <li>📥 <b>2. Load & First Look</b> — Shape, dtypes, head/tail, memory usage</li>
#     <li>🔍 <b>3. Data Quality Check</b>
#         <ul style="margin:6px 0 0 0; line-height:1.8;">
#           <li>Missing values & null patterns</li>
#           <li>Duplicate detection</li>
#           <li>Unique value counts per column</li>
#         </ul>
#     </li>
#     <li>🎯 <b>4. Target Variable Analysis</b> — Class distribution, balance check</li>
#     <li>📈 <b>5. Univariate Analysis</b>
#         <ul style="margin:6px 0 0 0; line-height:1.8;">
#           <li>Histograms with Mean/Median lines</li>
#           <li>Box plots for outlier detection</li>
#           <li>Categorical bar charts with labels</li>
#         </ul>
#     </li>
#     <li>🔗 <b>6. Bivariate Analysis</b>
#         <ul style="margin:6px 0 0 0; line-height:1.8;">
#           <li>Numeric features vs Heart Disease</li>
#           <li>Stacked % bar charts per category</li>
#           <li>Age distribution overlay by disease status</li>
#           <li>Age vs Max HR scatter (50K sample)</li>
#         </ul>
#     </li>
#     <li>🌡️ <b>7. Correlation Analysis</b> — Full heatmap + sorted feature-target bar chart</li>
#     <li>🧪 <b>8. Statistical Tests</b> — T-Test (numeric) + Chi-Square (categorical)</li>
#     <li>🎻 <b>9. Advanced Plots</b> — Violin plots, Heart Disease rate by Age Group</li>
#   </ul>
# </div>
#
# <!-- ===== Key Features Card ===== -->
# <div style="font-family:'Montserrat',sans-serif;
#             background:linear-gradient(135deg, #dcfce7 0%, #f0fdf4 100%);
#             padding:20px 22px;
#             border-radius:16px;
#             border:2px solid #86efac;
#             box-shadow:0 6px 20px rgba(34,197,94,0.12);
#             color:#2a2a2a;
#             margin-bottom:20px;">
#   <div style="display:flex; align-items:center; gap:10px; margin-bottom:10px;">
#     <span style="font-size:22px;">✨</span>
#     <h3 style="margin:0; font-size:18px; color:#15803d; font-weight:700;">Key Features of This Analysis</h3>
#   </div>
#   <ul style="margin:10px 0 0 20px; padding:0; line-height:1.9; font-size:15px;">
#     <li>🫀 <b>Medical Context:</b> Every feature explained in plain English for non-medical engineers</li>
#     <li>🧹 <b>Robust Preprocessing:</b> Winsorization, log transforms, rare category handling</li>
#     <li>📊 <b>Statistical Rigor:</b> T-Tests and Chi-Square tests confirm all visual findings</li>
#     <li>🎨 <b>Rich Visualizations:</b> Matplotlib + Seaborn + interactive Plotly charts</li>
#     <li>🔍 <b>Feature Intelligence:</b> Full ranking of 13 features by predictive power</li>
#     <li>💡 <b>Beginner Friendly:</b> Every plot includes a clear insight comment</li>
#     <li>💾 <b>ML Ready:</b> Preprocessing action plan + model recommendations included</li>
#     <li>📋 <b>Professional Summary:</b> Actionable conclusions in the final cell</li>
#   </ul>
# </div>
#
# <!-- ===== Analysis Types Card ===== -->
# <div style="font-family:'Montserrat',sans-serif;
#             background:linear-gradient(135deg, #ffe4f3 0%, #fff5fa 100%);
#             padding:20px 22px;
#             border-radius:16px;
#             border:2px solid #fbbfdb;
#             box-shadow:0 6px 20px rgba(236,72,153,0.1);
#             color:#2a2a2a;
#             margin-bottom:20px;">
#   <div style="display:flex; align-items:center; gap:10px; margin-bottom:10px;">
#     <span style="font-size:22px;">📊</span>
#     <h3 style="margin:0; font-size:18px; color:#be185d; font-weight:700;">Types of Analysis Performed</h3>
#   </div>
#
#   <div style="margin:12px 0;">
#     <h4 style="margin:8px 0 6px 0; color:#db2777; font-size:16px;">🔹 Univariate Analysis</h4>
#     <ul style="margin:6px 0 0 20px; padding:0; line-height:1.8; font-size:14px;">
#       <li>Distribution shape for all 5 numeric features</li>
#       <li>Skewness detection (Mean vs Median comparison)</li>
#       <li>Category frequency counts for all 8 categorical features</li>
#     </ul>
#   </div>
#
#   <div style="margin:12px 0;">
#     <h4 style="margin:8px 0 6px 0; color:#db2777; font-size:16px;">🔹 Bivariate Analysis</h4>
#     <ul style="margin:6px 0 0 20px; padding:0; line-height:1.8; font-size:14px;">
#       <li>Each feature vs Heart Disease (Presence/Absence)</li>
#       <li>Box plots reveal median shifts between disease groups</li>
#       <li>Stacked bars reveal risk rates per category</li>
#     </ul>
#   </div>
#
#   <div style="margin:12px 0;">
#     <h4 style="margin:8px 0 6px 0; color:#db2777; font-size:16px;">🔹 Multivariate Analysis</h4>
#     <ul style="margin:6px 0 0 20px; padding:0; line-height:1.8; font-size:14px;">
#       <li>Full 13×13 correlation heatmap</li>
#       <li>Age × Max HR joint scatter colored by disease</li>
#       <li>Violin plots — simultaneous shape + separation view</li>
#     </ul>
#   </div>
# </div>
#
# <!-- ===== Technologies Card ===== -->
# <div style="font-family:'Montserrat',sans-serif;
#             background:linear-gradient(135deg, #e0f2fe 0%, #f0f9ff 100%);
#             padding:20px 22px;
#             border-radius:16px;
#             border:2px solid #7dd3fc;
#             box-shadow:0 6px 20px rgba(14,165,233,0.1);
#             color:#2a2a2a;">
#   <div style="display:flex; align-items:center; gap:10px; margin-bottom:10px;">
#     <span style="font-size:22px;">🛠️</span>
#     <h3 style="margin:0; font-size:18px; color:#0369a1; font-weight:700;">Technologies & Libraries</h3>
#   </div>
#   <div style="display:flex; flex-wrap:wrap; gap:10px; margin-top:12px;">
#     <span style="background:#fff; border:2px solid #0ea5e9; color:#0369a1;
#                  padding:6px 14px; border-radius:20px; font-size:13px; font-weight:600;">🐼 Pandas</span>
#     <span style="background:#fff; border:2px solid #3b82f6; color:#1e40af;
#                  padding:6px 14px; border-radius:20px; font-size:13px; font-weight:600;">🔢 NumPy</span>
#     <span style="background:#fff; border:2px solid #6366f1; color:#4338ca;
#                  padding:6px 14px; border-radius:20px; font-size:13px; font-weight:600;">📉 Matplotlib</span>
#     <span style="background:#fff; border:2px solid #8b5cf6; color:#6d28d9;
#                  padding:6px 14px; border-radius:20px; font-size:13px; font-weight:600;">🎨 Seaborn</span>
#     <span style="background:#fff; border:2px solid #e53e3e; color:#9b1c1c;
#                  padding:6px 14px; border-radius:20px; font-size:13px; font-weight:600;">📊 Plotly</span>
#     <span style="background:#fff; border:2px solid #f43f5e; color:#be123c;
#                  padding:6px 14px; border-radius:20px; font-size:13px; font-weight:600;">🧪 SciPy</span>
#     <span style="background:#fff; border:2px solid #10b981; color:#065f46;
#                  padding:6px 14px; border-radius:20px; font-size:13px; font-weight:600;">🤖 Scikit-learn (Next Step)</span>
#   </div>
# </div>
#
# <hr style="border:none; border-top:2px solid #fecaca; margin:25px 0;">
#
# <p style="text-align:center; font-family:'Montserrat',sans-serif; color:#e53e3e; font-size:14px; margin-top:20px; font-weight:600;">
#   🫀 <i>Scroll down to explore the complete analysis — every plot tells a story about heart health!</i> 📊
# </p>
#
# <hr style="border:none; border-top:2px solid #fecaca; margin:25px 0;">

# %% [markdown]
# <!-- ===== About the Author ===== -->
# <p style="background: linear-gradient(90deg, #ff9a9e, #fecfef);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 22px;
#          text-align: center;
#          color: #2c2c2c;
#          padding: 20px 42px;
#          border-radius: 30px;
#          border: 3px solid #ffa8c5;
#          box-shadow: 0 8px 20px rgba(255,140,170,0.2);
#          letter-spacing: 1.1px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 35px 0 18px;">
#   🧑‍💻 About the Author
# </p>
#
# <div style="font-family: 'Montserrat', sans-serif;
#             background: linear-gradient(135deg, #ffffff 0%, #fffbfe 100%);
#             border-radius: 18px;
#             padding: 28px;
#             border: 2px solid #ffe0ec;
#             box-shadow: 0 8px 24px rgba(255,107,157,0.12);
#             color: #2c2c2c;
#             margin-bottom: 25px;">
#   <p style="font-size: 16px; line-height: 1.8; margin: 0 0 14px 0;">
#     Hi, I'm <strong style="color:#ff1744; font-size:17px;">Asadullah Shehbaz</strong> —
#     an <strong>AI/ML Engineer</strong> and an active learner in
#     <strong>MLOps, LLMs, RAG Systems, and Vector Databases</strong>.
#   </p>
#   <p style="font-size: 16px; line-height: 1.8; margin: 0 0 16px 0;">
#     I focus on building <strong>end-to-end machine learning systems</strong>,
#     deploying intelligent APIs, and experimenting with
#     <strong>LLM-powered applications</strong> using modern AI stacks.
#   </p>
#   <blockquote style="background: linear-gradient(135deg, #e8f5e9 0%, #f1f8e9 100%);
#                      border-left: 5px solid #4caf50;
#                      padding: 16px 20px;
#                      font-style: italic;
#                      border-radius: 12px;
#                      color: #2c2c2c;
#                      margin: 16px 0 0 0;
#                      font-size: 15px;
#                      line-height: 1.7;
#                      box-shadow: 0 3px 10px rgba(76,175,80,0.1);">
#     💡 "Learning never stops in AI — we evolve by building, breaking, and rebuilding smarter systems."
#   </blockquote>
# </div>
#
# <!-- ===== Contact & Profiles ===== -->
# <p style="background: linear-gradient(90deg, #a8edea, #fed6e3);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 22px;
#          text-align: center;
#          color: #2c2c2c;
#          padding: 20px 42px;
#          border-radius: 30px;
#          border: 3px solid #81d4fa;
#          box-shadow: 0 8px 20px rgba(129,212,250,0.25);
#          letter-spacing: 1.1px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 30px 0 18px;">
#   🌐 Contact, Profiles & Portfolio
# </p>
#
# <div style="font-family: 'Montserrat', sans-serif;
#             background: linear-gradient(135deg, #ffffff 0%, #fafcff 100%);
#             border-radius: 18px;
#             padding: 28px;
#             border: 2px solid #d4ebff;
#             box-shadow: 0 8px 24px rgba(33,150,243,0.1);
#             color: #2c2c2c;">
#   <ul style="list-style: none;
#              padding: 0;
#              margin: 0;
#              display: flex;
#              flex-wrap: wrap;
#              gap: 12px;">
#     <li>
#       <a href="mailto:asadullahcreative@gmail.com"
#          style="background: linear-gradient(135deg, #fff3f3 0%, #ffe8e8 100%);
#                 padding: 11px 18px;
#                 border-radius: 12px;
#                 text-decoration: none;
#                 color: #d32f2f;
#                 font-weight: 600;
#                 font-size: 14px;
#                 border: 2px solid #ffcdd2;
#                 display: inline-block;
#                 transition: all 0.3s;
#                 box-shadow: 0 3px 8px rgba(211,47,47,0.1);">
#         📧 Email
#       </a>
#     </li>
#     <li>
#       <a href="https://www.linkedin.com/in/asadullah-shehbaz-18172a2bb/"
#          style="background: linear-gradient(135deg, #e3f2fd 0%, #e8eaf6 100%);
#                 padding: 11px 18px;
#                 border-radius: 12px;
#                 text-decoration: none;
#                 color: #1565c0;
#                 font-weight: 600;
#                 font-size: 14px;
#                 border: 2px solid #bbdefb;
#                 display: inline-block;
#                 transition: all 0.3s;
#                 box-shadow: 0 3px 8px rgba(21,101,192,0.1);">
#         🔗 LinkedIn
#       </a>
#     </li>
#     <li>
#       <a href="https://github.com/AsadullahShehbaz"
#          style="background: linear-gradient(135deg, #f5f5f5 0%, #eeeeee 100%);
#                 padding: 11px 18px;
#                 border-radius: 12px;
#                 text-decoration: none;
#                 color: #212121;
#                 font-weight: 600;
#                 font-size: 14px;
#                 border: 2px solid #e0e0e0;
#                 display: inline-block;
#                 transition: all 0.3s;
#                 box-shadow: 0 3px 8px rgba(33,33,33,0.1);">
#         💻 GitHub
#       </a>
#     </li>
#     <li>
#       <a href="https://www.kaggle.com/asadullahcreative"
#          style="background: linear-gradient(135deg, #e0f7fa 0%, #e1f5fe 100%);
#                 padding: 11px 18px;
#                 border-radius: 12px;
#                 text-decoration: none;
#                 color: #00838f;
#                 font-weight: 600;
#                 font-size: 14px;
#                 border: 2px solid #b2ebf2;
#                 display: inline-block;
#                 transition: all 0.3s;
#                 box-shadow: 0 3px 8px rgba(0,131,143,0.1);">
#         🧠 Kaggle
#       </a>
#     </li>
#     <li>
#       <a href="https://asadullahshehbaz.github.io/"
#          style="background: linear-gradient(135deg, #fff3e0 0%, #ffe0b2 100%);
#                 padding: 11px 18px;
#                 border-radius: 12px;
#                 text-decoration: none;
#                 color: #e65100;
#                 font-weight: 700;
#                 font-size: 14px;
#                 border: 2px solid #ffcc80;
#                 display: inline-block;
#                 transition: all 0.3s;
#                 box-shadow: 0 4px 12px rgba(230,81,0,0.15);">
#         🌐 Portfolio ⭐
#       </a>
#     </li>
#     <li>
#       <a href="https://x.com/C786Asadullah"
#          style="background: linear-gradient(135deg, #e3f2fd 0%, #e1f5fe 100%);
#                 padding: 11px 18px;
#                 border-radius: 12px;
#                 text-decoration: none;
#                 color: #0277bd;
#                 font-weight: 600;
#                 font-size: 14px;
#                 border: 2px solid #b3e5fc;
#                 display: inline-block;
#                 transition: all 0.3s;
#                 box-shadow: 0 3px 8px rgba(2,119,189,0.1);">
#         🐦 Twitter (X)
#       </a>
#     </li>
#   </ul>
# </div>
#
# ---
#
# <p style="text-align: center;
#           font-family: 'Montserrat', sans-serif;
#           color: #666;
#           font-size: 13px;
#           margin-top: 30px;
#           font-style: italic;">
#   ⭐ If you find this notebook helpful, please upvote and leave a comment!
# </p>

# %% [markdown]
# ## 📦 Step 1: Import Libraries

# %%
# Core Libraries
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Statistics
from scipy import stats

# Settings
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
sns.set_theme(style='whitegrid', palette='Set2')
plt.rcParams['figure.figsize'] = (10, 6)
import plotly.io as pio
pio.renderers.default = 'iframe'
print('✅ All libraries loaded successfully!')
# Out:
# ✅ All libraries loaded successfully!

# %% [markdown]
# ## 📂 Step 2: Load & First Look at Data

# %%
# Load the dataset
df = pd.read_csv('/kaggle/input/competitions/playground-series-s6e2/train.csv')  # Change filename as needed

print(f'📊 Dataset Shape: {df.shape}')
print(f'📝 Total Rows: {df.shape[0]:,}')
print(f'📋 Total Columns: {df.shape[1]}')
print('\n🔍 First 5 Rows:')
df.head()
# Out:
# 📊 Dataset Shape: (630000, 15)
# 📝 Total Rows: 630,000
# 📋 Total Columns: 15
#
# 🔍 First 5 Rows:
#    id  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   0   58    1                4  152          239             0            0
# 1   1   52    1                1  125          325             0            2
# 2   2   56    0                2  160          188             0            2
# 3   3   44    0                3  134          229             0            2
# 4   4   58    1                4  140          234             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     158                1            3.6            2
# 1     171                0            0.0            1
# 2     151                0            0.0            1
# 3     150                0            1.0            2
# 4     125                1            3.8            2
#
#    Number of vessels fluro  Thallium Heart Disease
# ...

# %% [markdown]
# ## 🫀 Feature Dictionary — What Every Column Really Means
# > 📖 No medical degree needed — each feature explained in plain English with ML importance rating
#
# ---
#
# ### 🔢 `id` — Row Identifier
# > ❌ **DROP — Zero ML Value**
#
# Patient registration number. Uniquely identifies a row but tells the model **nothing** about disease. Always drop before training.
#
# ---
#
# ### 🎂 `Age` — Patient Age (29–77 years)
# > ✅ **Moderate Predictor | corr: 0.21**
#
# Arteries stiffen and accumulate plaque with age. Risk jumps significantly after **55–60**. Think of it like a car engine — old engine = worn parts = higher failure risk. Risk threshold at ~55 is where disease cases overtake healthy ones.
#
# ---
#
# ### 🚻 `Sex` — 0=Female, 1=Male
# > ✅ **Strong Predictor | corr: 0.34**
#
# Males have **~55% disease rate** vs females at **~17%** — nearly 3× higher risk. Women are protected by estrogen until menopause. Already encoded as 0/1, no further preprocessing needed.
#
# ---
#
# ### 💢 `Chest pain type` — 4 Categories
# > 🔥 **Very Strong | corr: 0.46**
#
# **1**=Typical Angina | **2**=Atypical | **3**=Non-cardiac | **4**=Asymptomatic
#
# ⚠️ **Counterintuitive:** Type 4 (no pain at all) has the **highest disease rate ~70%**. Heart disease is a silent killer — no pain doesn't mean no disease.
#
# ---
#
# ### 🩸 `BP` — Systolic Blood Pressure (94–200 mmHg)
# > ⚠️ **Surprisingly Weak | corr: −0.01**
#
# Peak pressure when heart pumps blood. Medically famous risk factor — but **near-zero ML correlation** as a standalone feature. Key lesson: **medical importance ≠ ML importance**. Keep for ensemble models; don't over-rely on it alone.
#
# ---
#
# ### 🧈 `Cholesterol` — Blood Fat Level (126–564 mg/dL)
# > ⚠️ **Weak Standalone | corr: 0.08**
#
# LDL ("bad") cholesterol sticks to artery walls → builds plaque → narrowing → heart disease. Has upper outliers up to 564 — apply **Winsorization**. Weak alone but gains power in feature combinations.
#
# ---
#
# ### 🍬 `FBS over 120` — Fasting Blood Sugar Flag
# > ⚠️ **Weakest Feature | corr: 0.03**
#
# **0** = sugar ≤ 120 mg/dL | **1** = sugar > 120 mg/dL (diabetic signal). 92% of patients = 0, making it heavily imbalanced. Diabetes links to heart disease, but this binary flag alone carries very little predictive signal.
#
# ---
#
# ### 📈 `EKG results` — Heart Electrical Signal
# > ✅ **Moderate | corr: 0.22**
#
# **0**=Normal | **1**=ST-T Abnormality (only 1,322 cases — nearly noise!) | **2**=LV Hypertrophy (enlarged heart chamber)
#
# ⚠️ **Merge or drop category 1** — 0.2% of data confuses models more than it helps.
#
# ---
#
# ### 💓 `Max HR` — Peak Heart Rate During Stress Test (71–202 bpm)
# > 🔥 **Strong NEGATIVE | corr: −0.44**
#
# The **only negative predictor** — higher Max HR = healthier heart. Formula: `Expected Max HR = 220 − Age`. Patients who couldn't exceed 100 bpm during exercise are almost all disease cases. **Never drop a feature because its correlation is negative** — magnitude is what matters.
#
# ---
#
# ### 🏃 `Exercise angina` — Chest Pain During Exercise
# > 🔥 **Very Strong | corr: 0.44**
#
# **0**=No | **1**=Yes. No exercise pain → ~30% disease rate. Yes → **~80% disease rate**. Blockages invisible at rest reveal themselves when the heart demands more blood during exercise.
#
# ---
#
# ### 📉 `ST depression` — EKG Dip During Exercise (0–6.2 mm)
# > 🔥 **Strong | corr: 0.43**
#
# How much the EKG signal dips during exercise vs rest. Bigger dip = worse blockage. Absence median ≈ 0, Presence median ≈ 1.5. **Heavily right-skewed** — apply `np.log1p()` transformation before modeling.
#
# ---
#
# ### 📐 `Slope of ST` — EKG Signal Direction at Peak Exercise
# > 🔥 **Strong | corr: 0.42**
#
# **1**=Upsloping ✅ | **2**=Flat ⚠️ | **3**=Downsloping 🔴
#
# Works hand-in-hand with ST depression. Downsloping at peak exercise = one of the most reliable disease markers in cardiology.
#
# ---
#
# ### 🔬 `Number of vessels fluro` — Blocked Arteries Count (0–3)
# > 🔥 **Very Strong | corr: 0.44**
#
# Live X-ray counts physically blocked arteries: **0→30%**, **1→70%**, **2→88%**, **3→90%+** disease rate. A perfect monotonic relationship — every additional blocked artery increases risk. Most direct physical measurement of disease severity.
#
# ---
#
# ### ☢️ `Thallium` — Nuclear Blood Flow Imaging
# > 👑 **#1 Predictor | corr: 0.61**
#
# **3**=Normal ✅ | **6**=Fixed Defect (old heart attack scar) 🔴 | **7**=Reversible Defect (blockage under stress) 🔴
#
# The **single strongest predictor**. Directly photographs blood flow inside heart muscle. Reversible defect = ~70% disease rate. Normal = ~20%.
#
# ---
#
# ### 🎯 `Heart Disease` — TARGET VARIABLE
# > 🏷️ **PREDICT THIS**
#
# Final diagnosis: **"Presence"** (44.8% → 282,454 patients) or **"Absence"** (55.2% → 347,546 patients). Nearly balanced — no SMOTE needed.
# ```python
# df['Heart Disease'] = df['Heart Disease'].map({'Presence': 1, 'Absence': 0})
# ```

# %%
# Column info - what data types do we have?
print('📌 Column Names and Data Types:')
print(df.dtypes)
print('\n📌 Detailed Info:')
df.info()
# Out:
# 📌 Column Names and Data Types:
# id                           int64
# Age                          int64
# Sex                          int64
# Chest pain type              int64
# BP                           int64
# Cholesterol                  int64
# FBS over 120                 int64
# EKG results                  int64
# Max HR                       int64
# Exercise angina              int64
# ST depression              float64
# Slope of ST                  int64
# Number of vessels fluro      int64
# Thallium                     int64
# Heart Disease               object
# dtype: object
#
# 📌 Detailed Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630000 entries, 0 to 629999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       630000 non-null  int64
#  1   Age                      630000 non-null  int64
# ...

# %%
# Basic statistics for numeric columns
print('📊 Statistical Summary:')
df.describe().round(2)
# Out:
# 📊 Statistical Summary:
#               id        Age        Sex  Chest pain type         BP  \
# count  630000.00  630000.00  630000.00        630000.00  630000.00
# mean   314999.50      54.14       0.71             3.31     130.50
# std    181865.48       8.26       0.45             0.85      14.98
# min         0.00      29.00       0.00             1.00      94.00
# 25%    157499.75      48.00       0.00             3.00     120.00
# 50%    314999.50      54.00       1.00             4.00     130.00
# 75%    472499.25      60.00       1.00             4.00     140.00
# max    629999.00      77.00       1.00             4.00     200.00
#
#        Cholesterol  FBS over 120  EKG results     Max HR  Exercise angina  \
# count    630000.00     630000.00    630000.00  630000.00        630000.00
# mean        245.01          0.08         0.98     152.82             0.27
# std          33.68          0.27         1.00      19.11             0.45
# ...

# %% [markdown]
# ## 🔍 Step 3: Data Quality Check
# > **Why?** Before analysis, always check: missing values, duplicates, and data types

# %%
# ---- CHECK 1: Missing Values ----
print('='*45)
print('🔴 MISSING VALUES CHECK')
print('='*45)
missing = df.isnull().sum()
missing_pct = (missing / len(df)) * 100
missing_df = pd.DataFrame({'Missing Count': missing, 'Missing %': missing_pct.round(2)})
print(missing_df)
print(f'\n✅ Total missing values: {missing.sum()}')
# Out:
# ...
# 🔴 MISSING VALUES CHECK
# ...
#                          Missing Count  Missing %
# id                                   0        0.0
# Age                                  0        0.0
# Sex                                  0        0.0
# Chest pain type                      0        0.0
# BP                                   0        0.0
# Cholesterol                          0        0.0
# FBS over 120                         0        0.0
# EKG results                          0        0.0
# Max HR                               0        0.0
# Exercise angina                      0        0.0
# ST depression                        0        0.0
# Slope of ST                          0        0.0
# Number of vessels fluro              0        0.0
# Thallium                             0        0.0
# Heart Disease                        0        0.0
#
# ✅ Total missing values: 0

# %%
# ---- CHECK 2: Duplicates ----
print('='*45)
print('🔴 DUPLICATES CHECK')
print('='*45)
dup_count = df.duplicated().sum()
print(f'Duplicate rows: {dup_count}')
print('✅ No duplicates!' if dup_count == 0 else f'⚠️ Found {dup_count} duplicate rows!')
# Out:
# ...
# 🔴 DUPLICATES CHECK
# ...
# Duplicate rows: 0
# ✅ No duplicates!

# %%
df.drop(columns="id",inplace=True)

# %%
# ---- CHECK 3: Unique Values per Column ----
print('='*45)
print('📊 UNIQUE VALUES PER COLUMN')
print('='*45)
unique_vals = df.nunique().reset_index()
unique_vals.columns = ['Column', 'Unique Values']

fig = px.bar(unique_vals, x='Column', y='Unique Values',
             title='Unique Values Count per Column',
             color='Unique Values', color_continuous_scale='Blues',
             text='Unique Values')
fig.update_layout(xaxis_tickangle=-30)
fig.show()

print(unique_vals.to_string(index=False))
# Out:
# ...
# 📊 UNIQUE VALUES PER COLUMN
# ...
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_8.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
#                  Column  Unique Values
#                     Age             42
#                     Sex              2
#         Chest pain type              4
#                      BP             66
#             Cholesterol            150
#            FBS over 120              2
#             EKG results              3
#                  Max HR             93
#         Exercise angina              2
#           ST depression             66
#             Slope of ST              3
# Number of vessels fluro              4
#                Thallium              3
#           Heart Disease              2

# %% [markdown]
# 📊 Unique Values — Key Takeaways
#
# 1. **Cholesterol (150), Max HR (93), BP & ST depression (66)** are true continuous features — scale them before modeling.
#
# 2. **Sex, FBS, Exercise angina (2 values), EKG, Slope, Thallium (3 values)** are categoricals hiding as integers — consider One-Hot Encoding for linear models.
#
# 3. **Simple rule from this chart:** ≤ 4 unique values = treat as categorical | 40+ unique values = treat as numerical. Your entire preprocessing strategy in one glance.

# %% [markdown]
# ## 🎯 Step 4: Target Variable Analysis
# > **Target column:** `Heart Disease` (Presence vs Absence)
# > This is what our ML model will predict — always analyze it first!

# %%
# Target Distribution
target_counts = df['Heart Disease'].value_counts()
target_pct = df['Heart Disease'].value_counts(normalize=True) * 100

print('🎯 Target Variable Distribution:')
print(f'  Presence : {target_counts["Presence"]:,} ({target_pct["Presence"]:.1f}%)')
print(f'  Absence  : {target_counts["Absence"]:,} ({target_pct["Absence"]:.1f}%)')
# Out:
# 🎯 Target Variable Distribution:
#   Presence : 282,454 (44.8%)
#   Absence  : 347,546 (55.2%)

# %%
# Plot
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Bar chart
colors = ['#E74C3C', '#2ECC71']
axes[0].bar(target_counts.index, target_counts.values, color=colors, edgecolor='black', linewidth=0.8)
axes[0].set_title('Heart Disease Count', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Heart Disease Status')
axes[0].set_ylabel('Count')
for i, v in enumerate(target_counts.values):
    axes[0].text(i, v + 1000, f'{v:,}', ha='center', fontweight='bold')

# Pie chart
axes[1].pie(target_counts.values, labels=target_counts.index, autopct='%1.1f%%',
            colors=colors, startangle=90, explode=(0.05, 0))
axes[1].set_title('Heart Disease Distribution (%)', fontsize=14, fontweight='bold')

plt.suptitle('🎯 Target Variable Analysis', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('target_analysis.png', dpi=150, bbox_inches='tight')
plt.show()
print('💡 Insight: Check if dataset is balanced or imbalanced!')
# Out:
# 💡 Insight: Check if dataset is balanced or imbalanced!

# %% [markdown]
# 🎯 Target Variable — Key Takeaways
#
# 1. **Nearly balanced** — 55.2% Absence vs 44.8% Presence. No SMOTE or resampling needed.
#
# 2. **Accuracy is valid here** — but still prefer **F1-Score + ROC-AUC** for any medical classification task.
#
# > 💡 **Rule:** Split worse than 80/20 → worry about imbalance. This 55/45 split is as clean as it gets in real-world medical data.

# %% [markdown]
# ## 📊 Step 5: Univariate Analysis
# > **Univariate = Analyzing ONE variable at a time**
# > Check the shape, spread, and outliers of each feature

# %%
# Encode target for analysis
df['target_num'] = (df['Heart Disease'] == 'Presence').astype(int)

# Define numeric features (excluding id and target)
numeric_cols = ['Age', 'BP', 'Cholesterol', 'Max HR', 'ST depression']
categorical_cols = ['Sex', 'Chest pain type', 'FBS over 120', 'EKG results',
                    'Exercise angina', 'Slope of ST', 'Number of vessels fluro', 'Thallium']

print('✅ Numeric columns:', numeric_cols)
print('✅ Categorical columns:', categorical_cols)
# Out:
# ✅ Numeric columns: ['Age', 'BP', 'Cholesterol', 'Max HR', 'ST depression']
# ✅ Categorical columns: ['Sex', 'Chest pain type', 'FBS over 120', 'EKG results', 'Exercise angina', 'Slope of ST', 'Number of vessels fluro', 'Thallium']

# %%
# Histograms for Numeric Features
fig, axes = plt.subplots(2, 3, figsize=(16, 10))
axes = axes.flatten()

for i, col in enumerate(numeric_cols):
    axes[i].hist(df[col], bins=40, color='steelblue', edgecolor='black', alpha=0.8)
    axes[i].axvline(df[col].mean(), color='red', linestyle='--', linewidth=2, label=f'Mean: {df[col].mean():.1f}')
    axes[i].axvline(df[col].median(), color='green', linestyle='-', linewidth=2, label=f'Median: {df[col].median():.1f}')
    axes[i].set_title(f'Distribution of {col}', fontsize=12, fontweight='bold')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Frequency')
    axes[i].legend(fontsize=9)

axes[5].axis('off')  # Hide last empty subplot
plt.suptitle('📊 Numeric Features Distribution', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('numeric_distributions.png', dpi=150, bbox_inches='tight')
plt.show()
print('💡 Red dashed = Mean | Green solid = Median')
print('💡 If Mean ≠ Median → Distribution is SKEWED')
# Out:
# 💡 Red dashed = Mean | Green solid = Median
# 💡 If Mean ≠ Median → Distribution is SKEWED

# %% [markdown]
# 📊 Numeric Features Distribution — Key Takeaways
#
# 1. **Age & Cholesterol are nearly symmetric** — Mean ≈ Median (54.1≈54.0 and 245≈243), bell-shaped distributions. These are the cleanest features, minimal preprocessing needed.
#
# 2. **BP shows multimodal peaks** (spikes at 120, 130, 140) — likely due to doctors rounding to nearest 10. Normal behavior in real medical data, not a data error.
#
# 3. **Max HR is left-skewed** — Mean (152.8) < Median (157.0), meaning a tail of patients with dangerously low max heart rates pulling the average down. Those low-HR patients are likely your disease cases.
#
# 4. **ST depression is heavily right-skewed** — Median is just 0.1 but Mean is 0.7, with a long tail reaching 6+. Most patients have near-zero depression, but disease patients spike it high. Consider **log transformation** to handle this skew.
#
# > 💡 **Beginner Rule:** Mean ≈ Median → symmetric, safe to use raw. Mean >> Median → right skew → apply `log1p()`. Mean << Median → left skew → consider `square` transformation.

# %%
# Box Plots - Find Outliers!
fig, axes = plt.subplots(1, 5, figsize=(20, 6))

for i, col in enumerate(numeric_cols):
    axes[i].boxplot(df[col], patch_artist=True,
                    boxprops=dict(facecolor='lightblue', color='navy'),
                    medianprops=dict(color='red', linewidth=2),
                    flierprops=dict(marker='o', markerfacecolor='orange', markersize=2))
    axes[i].set_title(col, fontsize=11, fontweight='bold')
    axes[i].set_ylabel('Value')

plt.suptitle('📦 Box Plots - Outlier Detection', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('boxplots.png', dpi=150, bbox_inches='tight')
plt.show()
print('💡 Dots outside the whiskers = OUTLIERS')
print('💡 Box = Middle 50% of data (IQR)')
# Out:
# 💡 Dots outside the whiskers = OUTLIERS
# 💡 Box = Middle 50% of data (IQR)

# %% [markdown]
# 📦 Box Plots — Key Takeaways
#
# 1. **Age has almost no outliers** — tight, clean distribution. Most patients are 45–60, a few rare cases below 35. Safest feature, use as-is.
#
# 2. **BP & Cholesterol have notable upper outliers** — BP reaching ~200, Cholesterol spiking ~560+. These are medically possible (hypertensive crisis, extreme hypercholesterolemia) so **don't delete them** — they likely belong to severe disease cases.
#
# 3. **ST depression has the most dense outlier cloud** — the box sits near zero but dots scatter all the way to 6+. Confirms the heavy right-skew seen earlier. Apply `log1p()` transformation before modeling.
#
# 4. **Max HR has the widest IQR (box size)** — meaning high natural variability between patients. Also has a few very low outliers (~75 bpm) which are clinically significant — those patients' hearts couldn't accelerate, strong disease signal.
#
# > 💡 **Beginner Rule:** Outliers in medical data = **don't blindly remove them.** Use **IQR capping (Winsorization)** instead — clip extreme values to the 1st and 99th percentile rather than deleting rows.

# %%
from scipy.stats import mstats
df['Cholesterol'] = mstats.winsorize(df['Cholesterol'], limits=[0.01, 0.01])

# %%
# Categorical Features - Bar Charts
fig, axes = plt.subplots(2, 4, figsize=(20, 10))
axes = axes.flatten()

cat_labels = {
    'Sex': {0: 'Female', 1: 'Male'},
    'Chest pain type': {1: 'Typical Angina', 2: 'Atypical', 3: 'Non-anginal', 4: 'Asymptomatic'},
    'FBS over 120': {0: 'No', 1: 'Yes'},
    'EKG results': {0: 'Normal', 1: 'ST-T Abnorm', 2: 'LV Hypertrophy'},
    'Exercise angina': {0: 'No', 1: 'Yes'},
    'Slope of ST': {1: 'Upsloping', 2: 'Flat', 3: 'Downsloping'},
    'Number of vessels fluro': {0: '0', 1: '1', 2: '2', 3: '3'},
    'Thallium': {3: 'Normal', 6: 'Fixed Defect', 7: 'Reversible'}
}

for i, col in enumerate(categorical_cols):
    val_counts = df[col].value_counts().sort_index()
    labels = [cat_labels[col].get(k, str(k)) for k in val_counts.index]
    axes[i].bar(labels, val_counts.values, color=sns.color_palette('Set2', len(val_counts)),
                edgecolor='black', linewidth=0.5)
    axes[i].set_title(col, fontsize=11, fontweight='bold')
    axes[i].set_ylabel('Count')
    axes[i].tick_params(axis='x', rotation=20)
    for j, v in enumerate(val_counts.values):
        axes[i].text(j, v + 200, f'{v:,}', ha='center', fontsize=8)

plt.suptitle('📊 Categorical Features Distribution', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('categorical_distributions.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# 📊 Categorical Features Distribution — Key Takeaways
#
# 1. **Males dominate at 71.5%** (450,283 vs 179,717) — dataset is gender-imbalanced. Model may be slightly biased toward male patterns, keep this in mind during evaluation.
#
# 2. **Asymptomatic chest pain (329,179) is the largest group** — over 52% of patients reported no chest pain yet many have disease. Reinforces the earlier insight: heart disease is often silent and dangerous.
#
# 3. **FBS over 120 is heavily skewed** — 91.9% patients (579,608) have normal blood sugar. This class imbalance makes FBS a **weak standalone predictor** — low information gain for most models.
#
# 4. **EKG results: ST-T Abnormality is nearly absent** (only 1,322 cases) — this category is so rare it's almost noise. Consider **merging it with LV Hypertrophy** or dropping it to avoid misleading the model.
#
# 5. **Number of vessels fluro & Thallium show natural disease progression** — majority have 0 blocked vessels (healthy) and Normal thallium, but Reversible defect (246,748) is surprisingly high — nearly 40% — a strong disease signal worth noting.
#
# > 💡 **Beginner Rule:** If one category has < 1% of total rows (like ST-T Abnorm with 1,322/630,000 = 0.2%), consider merging or dropping it — rare categories confuse models more than they help.

# %% [markdown]
# ## 🔗 Step 6: Bivariate Analysis
# > **Bivariate = Analyzing TWO variables together**
# > How does each feature relate to Heart Disease?

# %%
# Numeric Features vs Heart Disease - Box Plots
fig, axes = plt.subplots(1, 5, figsize=(22, 6))
palette = {'Presence': '#E74C3C', 'Absence': '#2ECC71'}

for i, col in enumerate(numeric_cols):
    df.boxplot(column=col, by='Heart Disease', ax=axes[i],
               patch_artist=True,
               boxprops=dict(linewidth=1.2))
    axes[i].set_title(col, fontsize=11, fontweight='bold')
    axes[i].set_xlabel('Heart Disease')
    
plt.suptitle('📦 Numeric Features vs Heart Disease', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('bivariate_numeric.png', dpi=150, bbox_inches='tight')
plt.show()
print('💡 If boxes are at different heights → Feature is USEFUL for prediction!')
# Out:
# 💡 If boxes are at different heights → Feature is USEFUL for prediction!

# %% [markdown]
# 📦 Numeric Features vs Heart Disease — Key Takeaways
#
# 1. **Age & Cholesterol boxes barely differ** between Absence/Presence — small median shift only. Weak individual predictors, but still valuable in combination with other features.
#
# 2. **BP shows almost identical boxes** for both classes — surprisingly poor separator on its own. Don't over-rely on it as a standalone feature despite its medical reputation.
#
# 3. **Max HR is the clearest separator** — Absence group sits noticeably higher (median ~168) vs Presence (median ~150). Lower max HR = stronger disease signal. **Best numeric predictor of the five.**
#
# 4. **ST depression tells the strongest story** — Absence median is near 0, Presence median jumps to ~1.5 with a much wider spread. The bigger the gap between two boxes, the more useful that feature is for your model.
#
# > 💡 **Beginner Rule:** When two box plots have **clearly different median lines** → feature is a strong predictor. When boxes **heavily overlap** → feature alone won't help much. Max HR and ST depression are your star numeric features here.

# %%
# Categorical Features vs Heart Disease - Stacked Bar
fig, axes = plt.subplots(2, 4, figsize=(22, 12))
axes = axes.flatten()

for i, col in enumerate(categorical_cols):
    ct = pd.crosstab(df[col], df['Heart Disease'], normalize='index') * 100
    ct.plot(kind='bar', stacked=True, ax=axes[i],
            color=['#2ECC71', '#E74C3C'], edgecolor='black', linewidth=0.5)
    axes[i].set_title(f'{col}\nvs Heart Disease (%)', fontsize=10, fontweight='bold')
    axes[i].set_xlabel('')
    axes[i].set_ylabel('Percentage (%)')
    axes[i].tick_params(axis='x', rotation=30)
    axes[i].legend(title='Disease', fontsize=8)
    axes[i].axhline(y=50, color='gray', linestyle='--', alpha=0.5)

plt.suptitle('📊 Categorical Features vs Heart Disease (Stacked %)', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('bivariate_categorical.png', dpi=150, bbox_inches='tight')
plt.show()
print('💡 More RED = Higher disease risk for that category')
# Out:
# 💡 More RED = Higher disease risk for that category

# %% [markdown]
# 📊 Categorical Features vs Heart Disease — Key Takeaways
#
# 1. **Sex is a strong separator** — Females (0) have ~17% disease rate, Males (1) spike to ~55%. Being male nearly triples the risk in this dataset.
#
# 2. **Chest pain type 4 (Asymptomatic) is the most dangerous** — ~70% disease rate despite no pain reported. Type 1 (Typical Angina) is paradoxically the safest. Classic silent killer pattern confirmed.
#
# 3. **Exercise angina is the cleanest binary separator** — No exercise angina (0) → ~30% disease. Yes (1) → ~80% disease. The single most decisive categorical feature visually.
#
# 4. **Number of vessels fluro shows perfect disease progression** — 0 vessels blocked → ~30% disease, 1 → ~70%, 2 → ~88%, 3 → ~90%+. A textbook monotonic relationship — more blockage = more disease, every single step.
#
# 5. **Thallium Reversible defect (7) → ~70% disease rate** vs Normal (3) → ~20%. Fixed Defect (6) sits in between. Directly mirrors physical blood flow damage making it one of the top predictors alongside vessels fluro.
#
# > 💡 **Beginner Rule:** The more the red/green ratio **flips dramatically** across categories, the more predictive that feature is. Exercise angina and Vessels fluro are your **star categorical features** — their bars flip almost completely.

# %%
# Age Distribution by Heart Disease
fig = px.histogram(df, x='Age', color='Heart Disease',
                   barmode='overlay',
                   nbins=40,
                   color_discrete_map={'Presence': '#E74C3C', 'Absence': '#2ECC71'},
                   title='🎂 Age Distribution by Heart Disease Status',
                   opacity=0.7)
fig.update_layout(xaxis_title='Age', yaxis_title='Count')
fig.show()
print('💡 Overlapping area shows similar age groups — differences show risk patterns')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_18.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# 💡 Overlapping area shows similar age groups — differences show risk patterns

# %% [markdown]
# 🎂 Age Distribution by Heart Disease — Key Takeaways
#
# 1. **Under 50 → almost entirely green** — disease cases are rare below age 50, healthy patients dominate completely. Young age is a strong protective factor.
#
# 2. **The crossover happens at ~55** — red starts competing with green seriously from age 55 onwards. This is the critical risk threshold in this dataset.
#
# 3. **Age 58–62 is the danger zone** — red overtakes green, disease cases become the majority. Peak disease concentration sits right here.
#
# 4. **Both groups drop after 65** — simply fewer elderly patients in the dataset, not that old age is safer. Don't misread the falling bars as reduced risk.
#
# > 💡 **Beginner Rule:** Where green dominates = model should predict Absence. Where red overtakes = model should lean toward Presence. This is exactly what **Age as a feature** teaches your model — a natural risk threshold around 55–60 that tree-based models like Random Forest will automatically learn to split on.

# %%
# Scatter Plot: Age vs Max HR colored by Heart Disease
# (Sampling 5,0000 points to keep it fast)
sample = df.sample(50000, random_state=42)

fig = px.scatter(sample, x='Age', y='Max HR',
                 color='Heart Disease',
                 color_discrete_map={'Presence': '#E74C3C', 'Absence': '#2ECC71'},
                 title='💓 Age vs Max Heart Rate (sampled 50K)',
                 opacity=0.5,
                 hover_data=['BP', 'Cholesterol'])
fig.show()
print('💡 Patients with lower Max HR tend to have more Heart Disease')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_19.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# 💡 Patients with lower Max HR tend to have more Heart Disease

# %% [markdown]
# 💓 Age vs Max Heart Rate — Key Takeaways
#
# 1. **Green dominates the top, red dominates the bottom** — healthy patients (Absence) consistently achieve higher Max HR, disease patients (Presence) cluster in the lower half. A clear horizontal separation exists around **Max HR ~150**.
#
# 2. **Age alone doesn't separate well** — red and green dots appear across ALL age groups side by side. But **Max HR draws a cleaner boundary** than Age does — confirming Max HR is the stronger individual predictor of the two.
#
# 3. **The bottom floor (Max HR < 100) is almost entirely red** — patients who couldn't push their heart above 100 bpm during exercise are nearly all disease cases. A very reliable danger zone.
#
# > 💡 **Beginner Rule:** When a scatter plot shows one class **floating above** and the other **sinking below** — that's exactly the kind of pattern a **Logistic Regression decision boundary** or a **Random Forest split** will learn to exploit. Age + Max HR together form a powerful 2D feature combination worth engineering: `df['Age_MaxHR_ratio'] = df['Age'] / df['Max HR']`

# %% [markdown]
# ## 🌡️ Step 7: Correlation Analysis
# > Correlation tells us HOW STRONGLY two numeric variables move together
# > Range: -1 (opposite) to +1 (same direction), 0 = no relationship

# %%
# Correlation Matrix Heatmap
corr_cols = numeric_cols + categorical_cols + ['target_num']
corr_matrix = df[corr_cols].corr().round(2)

fig, ax = plt.subplots(figsize=(14, 11))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))  # Show only lower triangle

sns.heatmap(corr_matrix,
            mask=mask,
            annot=True,
            fmt='.2f',
            cmap='RdYlGn',
            center=0,
            vmin=-1, vmax=1,
            linewidths=0.5,
            ax=ax,
            annot_kws={'size': 9})

ax.set_title('🌡️ Correlation Matrix Heatmap', fontsize=16, fontweight='bold', pad=15)
plt.tight_layout()
plt.savefig('correlation_heatmap.png', dpi=150, bbox_inches='tight')
plt.show()
print('💡 Last row (target_num) shows which features correlate most with Heart Disease')
# Out:
# 💡 Last row (target_num) shows which features correlate most with Heart Disease

# %% [markdown]
# 🌡️ Correlation Matrix Heatmap — Key Takeaways
#
# 1. **Thallium (0.61) is the single strongest predictor** of heart disease — by far the darkest green in the target row. Physical blood flow imaging beats every other measurement in this dataset.
#
# 2. **Top 5 features by target correlation (bottom row):**
#    - Thallium `0.61` 🥇
#    - Chest pain type `0.46` 🥈
#    - Exercise angina `0.44` 🥉
#    - Slope of ST `0.42`
#    - Vessels fluro `0.44`
#
# 3. **Max HR is the only negative correlator (−0.44)** — the orange cell stands out. Higher Max HR = lower disease risk. It works *opposite* to all other features — your model needs to learn this inverse relationship.
#
# 4. **BP, Cholesterol, FBS are near-zero with target** — correlations of −0.01, 0.08, 0.03 respectively. Statistically weak individual predictors despite their medical reputation. Don't over-feature-engineer these.
#
# 5. **No multicollinearity problem** — no two features show correlation above 0.50 with each other. This means **no redundant features to drop** — all 13 features carry unique information and should be kept.
#
# > 💡 **Beginner Rule:** Correlation with target > 0.3 = definitely keep. Near 0 = weak alone but keep for ensemble models. > 0.8 between two features = multicollinearity, drop one. This heatmap is your **feature selection cheat sheet**.

# %%
# Feature Correlation with Target (Sorted Bar Chart)
target_corr = df[corr_cols].corr()['target_num'].drop('target_num').sort_values()

colors = ['#E74C3C' if v > 0 else '#2ECC71' for v in target_corr.values]

fig, ax = plt.subplots(figsize=(10, 7))
bars = ax.barh(target_corr.index, target_corr.values, color=colors, edgecolor='black', linewidth=0.5)
ax.axvline(x=0, color='black', linewidth=1)
ax.set_title('🎯 Feature Correlation with Heart Disease', fontsize=14, fontweight='bold')
ax.set_xlabel('Correlation Coefficient')

for bar, val in zip(bars, target_corr.values):
    ax.text(val + (0.005 if val >= 0 else -0.005), bar.get_y() + bar.get_height()/2,
            f'{val:.2f}', va='center', ha='left' if val >= 0 else 'right', fontsize=9)

plt.tight_layout()
plt.savefig('feature_correlation.png', dpi=300, bbox_inches='tight')
plt.show()
print('💡 RED bars = Positive correlation (increases disease risk)')
print('💡 GREEN bars = Negative correlation (decreases disease risk)')
# Out:
# 💡 RED bars = Positive correlation (increases disease risk)
# 💡 GREEN bars = Negative correlation (decreases disease risk)

# %% [markdown]
# 🎯 Feature Correlation with Heart Disease — Key Takeaways
#
# 1. **Clear 3-tier feature ranking emerges:**
#    - 🔥 **Strong (>0.40):** Thallium, Chest pain type, Exercise angina, Vessels fluro, ST depression, Slope of ST — your core model features
#    - ⚠️ **Moderate (0.20–0.40):** Sex, EKG results, Age — supportive but not decisive
#    - ❌ **Weak (<0.10):** Cholesterol, FBS, BP — least individually useful
#
# 2. **Max HR is the lone green bar (−0.44)** — equal strength to the top positive predictors but works in reverse. Higher heart rate = healthier. Never drop a feature just because it's negative — its magnitude is what matters.
#
# 3. **BP (−0.01) is practically useless alone** — despite being medically famous, it contributes almost nothing as a standalone feature in this dataset. A good reminder that **medical importance ≠ ML importance**.
#
# 4. **Top 6 features alone cover the most signal** — Thallium through Slope of ST. If you ever need a lightweight model, these 6 + Max HR give you 7 features capturing nearly all predictive power.
#
# > 💡 **Beginner Rule:** This chart is your **feature importance preview** before even training a model. Sort features by `abs(correlation)` — that's your priority list. Features below 0.10 are candidates for dropping in simple models, but keep them for XGBoost/Random Forest which extract non-linear value even from weak features.

# %% [markdown]
# ## 🧪 Step 8: Statistical Tests
# > **Why?** Visualizations show patterns, but statistical tests PROVE them!
# > We use **T-test** for numeric features and **Chi-Square** for categorical features

# %%
# T-Test: Are means significantly different between Presence/Absence groups?
print('='*55)
print('🧪 T-TEST: Numeric Features vs Heart Disease')
print('='*55)
print(f"{'Feature':<25} {'T-Stat':>10} {'P-Value':>12} {'Significant?':>14}")
print('-'*65)

presence = df[df['Heart Disease'] == 'Presence']
absence = df[df['Heart Disease'] == 'Absence']

for col in numeric_cols:
    t_stat, p_val = stats.ttest_ind(presence[col], absence[col])
    sig = '✅ YES' if p_val < 0.05 else '❌ NO'
    print(f'{col:<25} {t_stat:>10.3f} {p_val:>12.4f} {sig:>14}')

print('\n💡 P-Value < 0.05 = Statistically SIGNIFICANT difference!')
print('💡 This means the feature IS useful for predicting Heart Disease')
# Out:
# ...
# 🧪 T-TEST: Numeric Features vs Heart Disease
# ...
# Feature                       T-Stat      P-Value   Significant?
# -----------------------------------------------------------------
# Age                          172.261       0.0000          ✅ YES
# BP                            -4.112       0.0000          ✅ YES
# Cholesterol                   67.401       0.0000          ✅ YES
# Max HR                      -389.989       0.0000          ✅ YES
# ST depression                378.727       0.0000          ✅ YES
#
# 💡 P-Value < 0.05 = Statistically SIGNIFICANT difference!
# 💡 This means the feature IS useful for predicting Heart Disease

# %%
# Chi-Square Test: Categorical Features vs Heart Disease
print('='*55)
print('🧪 CHI-SQUARE TEST: Categorical Features vs Heart Disease')
print('='*55)
print(f"{'Feature':<28} {'Chi-Stat':>10} {'P-Value':>12} {'Significant?':>14}")
print('-'*70)

for col in categorical_cols:
    ct = pd.crosstab(df[col], df['Heart Disease'])
    chi2, p_val, dof, expected = stats.chi2_contingency(ct)
    sig = '✅ YES' if p_val < 0.05 else '❌ NO'
    print(f'{col:<28} {chi2:>10.1f} {p_val:>12.4f} {sig:>14}')

print('\n💡 P-Value < 0.05 = Strong relationship with Heart Disease!')
# Out:
# ...
# 🧪 CHI-SQUARE TEST: Categorical Features vs Heart Disease
# ...
# Feature                        Chi-Stat      P-Value   Significant?
# ----------------------------------------------------------------------
# Sex                             73878.2       0.0000          ✅ YES
# Chest pain type                173770.7       0.0000          ✅ YES
# FBS over 120                      709.7       0.0000          ✅ YES
# EKG results                     30248.4       0.0000          ✅ YES
# Exercise angina                123001.4       0.0000          ✅ YES
# Slope of ST                    116357.6       0.0000          ✅ YES
# Number of vessels fluro        135190.5       0.0000          ✅ YES
# Thallium                       231215.7       0.0000          ✅ YES
#
# 💡 P-Value < 0.05 = Strong relationship with Heart Disease!

# %% [markdown]
# ## 📈 Step 9: Advanced Plots

# %%
# Violin Plot - Shows distribution SHAPE + median
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
key_features = ['Age', 'Max HR', 'ST depression']

for i, col in enumerate(key_features):
    sns.violinplot(data=df, x='Heart Disease', y=col, ax=axes[i],
                   palette={'Presence': '#E74C3C', 'Absence': '#2ECC71'},
                   inner='box')
    axes[i].set_title(f'{col} by Heart Disease', fontsize=12, fontweight='bold')

plt.suptitle('🎻 Violin Plots - Distribution Shape by Disease Status', fontsize=15, fontweight='bold')
plt.tight_layout()
plt.savefig('violin_plots.png', dpi=300, bbox_inches='tight')
plt.show()
print('💡 Wide = many data points at that value | Narrow = fewer data points')
# Out:
# 💡 Wide = many data points at that value | Narrow = fewer data points

# %% [markdown]
# 🎻 Violin Plots — Key Takeaways
#
# 1. **Age violins heavily overlap** — both groups peak around 55–60, confirming age alone is a weak separator. Disease patients skew slightly older but not decisively.
#
# 2. **Max HR violins shift clearly downward for Presence** — Absence is fatter/wider at 160–170 range, Presence bulges lower at 130–160. Clean separation confirms it's your strongest numeric predictor.
#
# 3. **ST depression is the most dramatic contrast** — Absence violin is almost entirely flat near 0 (razor thin), while Presence violin is wide and tall from 0–4, with a long tail to 6+. Two completely different distributions.
#
# > 💡 **Beginner Rule:** Violin width = how many patients have that value. **Fat at different heights = great predictor. Fat at same heights = weak predictor.** ST depression and Max HR show opposite bulge positions — exactly what a model needs to draw a decision boundary.

# %%
# Heart Disease Rate by Age Group
df['Age Group'] = pd.cut(df['Age'], bins=[29, 39, 49, 59, 69, 80],
                          labels=['30-39', '40-49', '50-59', '60-69', '70+'])

age_disease = df.groupby('Age Group', observed=True)['target_num'].mean() * 100

fig = px.bar(x=age_disease.index.astype(str), y=age_disease.values,
             title='📊 Heart Disease Rate by Age Group (%)',
             labels={'x': 'Age Group', 'y': 'Disease Rate (%)'},
             color=age_disease.values,
             color_continuous_scale='RdYlGn_r',
             text=age_disease.round(1).astype(str) + '%')
fig.update_traces(textposition='outside')
fig.show()
print('💡 Does disease risk increase with age?')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_25.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# 💡 Does disease risk increase with age?

# %% [markdown]
# # 📋 EDA Report
# ---
#
# ## 🗂️ Dataset Overview
# | Property | Detail |
# |---|---|
# | **Rows × Columns** | 630,000 × 14 (after dropping `id`) |
# | **Target** | `Heart Disease` → Binary (Presence / Absence) |
# | **Missing Values** | ✅ None |
# | **Duplicates** | ✅ None |
# | **Class Balance** | 55.2% Absence / 44.8% Presence — nearly balanced |
#
# ---
#
# ## 🔑 Top 10 Key Findings
#
# **1. Silent Disease is the Real Danger**
# Asymptomatic patients (no chest pain, type 4) showed the HIGHEST disease rate ~70%. Heart disease kills without warning — this is why Thallium imaging and stress tests matter.
#
# **2. Max HR is Your Most Unique Feature**
# The only negative correlator (−0.44). Patients who couldn't exceed 100 bpm during exercise were almost exclusively disease cases. Never drop a feature because it's negative.
#
# **3. ST Depression Has the Most Dramatic Separation**
# Absence median ≈ 0.0 vs Presence median ≈ 1.5. Two completely different distributions. Apply `log1p()` before modeling due to heavy right skew.
#
# **4. Vessels Fluro Tells a Perfect Story**
# 0 blocked → 30% disease | 1 blocked → 70% | 2 blocked → 88% | 3 blocked → 90%+. A textbook monotonic relationship — every additional blocked artery increases risk linearly.
#
# **5. BP and Cholesterol Underperform**
# Despite being medically famous risk factors, BP (−0.01) and Cholesterol (0.08) barely correlate with the target. Proof that **medical importance ≠ ML feature importance**.
#
# **6. Age Threshold at 55–60**
# Under 50 → almost entirely healthy. Disease dominates after 58. Tree-based models will naturally split here — Age is more useful as a threshold than a continuous value.
#
# **7. No Multicollinearity — All Features Safe to Keep**
# No two features exceed 0.50 correlation with each other. Zero redundant features. Use all 13 in your model confidently.
#
# **8. Males Are 3× More at Risk**
# 55% disease rate in males vs 17% in females within this dataset. Sex is a strong demographic separator.
#
# **9. EKG Rare Category Needs Handling**
# ST-T Abnormality has only 1,322 cases (0.2% of data). Merge with LV Hypertrophy or drop before modeling to prevent noise.
#
# **10. All 13 Features Are Statistically Significant**
# Every single feature passed T-Test and Chi-Square tests (p < 0.05). No feature is random — all carry real signal validated by statistics.
#
# ---
#
# ## 🤖 Recommended Models & Metrics
#
# | Model | Why Use It | Expected Strength |
# |---|---|---|
# | **XGBoost** | Handles mixed feature types, non-linear patterns | 🔥 Best expected |
# | **Random Forest** | Robust, no scaling needed, handles categoricals | ✅ Strong baseline |
# | **Logistic Regression** | Fast, interpretable, good probability output | ✅ Good benchmark |
# | **LightGBM** | Fastest on 630K rows, memory efficient | ✅ Production-ready |
#
# **Primary Metric:** `ROC-AUC` — handles both classes fairly
# **Secondary Metrics:** `F1-Score`, `Recall` — critical in medical diagnosis (missing a sick patient is worse than a false alarm)
#
# > ⚠️ **Never use Accuracy alone for medical classification.** A model predicting everyone as "Absence" would score 55% accuracy but miss every disease case — completely useless clinically.
#
# ---
# *EDA Completed ✅ | Next Step → Feature Engineering & Model Training 🚀*
