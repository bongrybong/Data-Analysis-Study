# %% [markdown]
# <div style="background: linear-gradient(135deg, #0f172a 0%, #1e1b4b 100%); padding: 35px; border-radius: 24px; font-family: 'Segoe UI', Roboto, Helvetica, Arial, sans-serif; box-shadow: 0 20px 45px rgba(0, 0, 0, 0.4); border: 1px solid rgba(255, 255, 255, 0.05); color: #f8fafc;">
#     <div style="display: flex; justify-content: space-between; align-items: center; border-bottom: 1px solid rgba(255, 255, 255, 0.1); padding-bottom: 25px; margin-bottom: 30px;">
#         <div>
#             <span style="background: linear-gradient(90deg, #ec4899, #8b5cf6); color: white; padding: 4px 12px; border-radius: 50px; font-size: 11px; font-weight: 800; text-transform: uppercase; letter-spacing: 2px; box-shadow: 0 0 15px rgba(236, 72, 153, 0.4);">
#                 Live Analytics App
#             </span>
#             <h1 style="color: #ffffff; font-size: 34px; font-weight: 800; margin: 10px 0 5px 0; letter-spacing: -0.5px; background: linear-gradient(to right, #ffffff, #94a3b8); -webkit-background-clip: text; -webkit-text-fill-color: transparent;">
#                 ❤️ Cardiovascular Health Insight Engine
#             </h1>
#             <p style="color: #94a3b8; font-size: 14px; margin: 0; font-weight: 400;">
#                 Advanced EDA & Multi-Model Predictive Framework
#             </p>
#         </div>
#         <div style="text-align: right;">
#             <div style="font-size: 13px; color: #a5b4fc; font-weight: 600;">System Status</div>
#             <div style="font-size: 14px; color: #34d399; font-weight: 700; margin-top: 4px; display: flex; align-items: center; gap: 6px; justify-content: flex-end;">
#                 <span style="width: 8px; height: 8px; background-color: #34d399; border-radius: 50%; display: inline-block; box-shadow: 0 0 8px #34d399;"></span> Ready to Deploy
#             </div>
#         </div>
#     </div>
#     <div style="display: flex; gap: 15px; margin-bottom: 35px; flex-wrap: wrap;">
#         <div style="flex: 1; min-width: 140px; background: rgba(255, 255, 255, 0.03); border: 1px solid rgba(255, 255, 255, 0.05); padding: 15px 20px; border-radius: 16px; backdrop-filter: blur(10px);">
#             <div style="color: #94a3b8; font-size: 12px; font-weight: 600; text-transform: uppercase;">Dataset</div>
#             <div style="color: #f1f5f9; font-size: 20px; font-weight: 700; margin-top: 5px;">Heart.csv</div>
#         </div>
#         <div style="flex: 1; min-width: 140px; background: rgba(255, 255, 255, 0.03); border: 1px solid rgba(255, 255, 255, 0.05); padding: 15px 20px; border-radius: 16px; backdrop-filter: blur(10px);">
#             <div style="color: #94a3b8; font-size: 12px; font-weight: 600; text-transform: uppercase;">Features</div>
#             <div style="color: #6366f1; font-size: 20px; font-weight: 700; margin-top: 5px;">14 Clinical</div>
#         </div>
#         <div style="flex: 1; min-width: 140px; background: rgba(255, 255, 255, 0.03); border: 1px solid rgba(255, 255, 255, 0.05); padding: 15px 20px; border-radius: 16px; backdrop-filter: blur(10px);">
#             <div style="color: #94a3b8; font-size: 12px; font-weight: 600; text-transform: uppercase;">Target</div>
#             <div style="color: #f43f5e; font-size: 20px; font-weight: 700; margin-top: 5px;">Binary Classification</div>
#         </div>
#         <div style="flex: 1; min-width: 140px; background: rgba(255, 255, 255, 0.03); border: 1px solid rgba(255, 255, 255, 0.05); padding: 15px 20px; border-radius: 16px; backdrop-filter: blur(10px);">
#             <div style="color: #94a3b8; font-size: 12px; font-weight: 600; text-transform: uppercase;">Author</div>
#             <div style="color: #38bdf8; font-size: 20px; font-weight: 700; margin-top: 5px; font-style: italic;">@YourName</div>
#         </div>
#     </div>
#     <h3 style="color: #f1f5f9; font-size: 16px; font-weight: 600; margin-bottom: 15px; text-transform: uppercase; letter-spacing: 1px;">
#         🎛️ Control Panel (Table of Contents)
#     </h3>
#     <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(220px, 1fr)); gap: 15px;">
#         <a href="#1" style="text-decoration: none; background: linear-gradient(135deg, rgba(99, 102, 241, 0.15) 0%, rgba(99, 102, 241, 0.05) 100%); border: 1px solid rgba(99, 102, 241, 0.2); padding: 18px; border-radius: 14px; transition: transform 0.2s; display: block;">
#             <div style="color: #a5b4fc; font-weight: 700; font-size: 15px;">01 // Setup</div>
#             <div style="color: #94a3b8; font-size: 12px; margin-top: 4px;">Environments & Ingestion</div>
#         </a>
#         <a href="#2" style="text-decoration: none; background: linear-gradient(135deg, rgba(236, 72, 153, 0.15) 0%, rgba(236, 72, 153, 0.05) 100%); border: 1px solid rgba(236, 72, 153, 0.2); padding: 18px; border-radius: 14px; transition: transform 0.2s; display: block;">
#             <div style="color: #f9a8d4; font-weight: 700; font-size: 15px;">02 // Visualization</div>
#             <div style="color: #94a3b8; font-size: 12px; margin-top: 4px;">Deep EDA & Feature Correlation</div>
#         </a>
#         <a href="#3" style="text-decoration: none; background: linear-gradient(135deg, rgba(56, 189, 248, 0.15) 0%, rgba(56, 189, 248, 0.05) 100%); border: 1px solid rgba(56, 189, 248, 0.2); padding: 18px; border-radius: 14px; transition: transform 0.2s; display: block;">
#             <div style="color: #7dd3fc; font-weight: 700; font-size: 15px;">03 // Preprocessing</div>
#             <div style="color: #94a3b8; font-size: 12px; margin-top: 4px;">Engineering & Scaling Pipeline</div>
#         </a>
#         <a href="#4" style="text-decoration: none; background: linear-gradient(135deg, rgba(52, 211, 153, 0.15) 0%, rgba(52, 211, 153, 0.05) 100%); border: 1px solid rgba(52, 211, 153, 0.2); padding: 18px; border-radius: 14px; transition: transform 0.2s; display: block;">
#             <div style="color: #6ee7b7; font-weight: 700; font-size: 15px;">04 // Modeling</div>
#             <div style="color: #94a3b8; font-size: 12px; margin-top: 4px;">Training & Hyperparameter Tuning</div>
#         </a>
#     </div>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #f8fafc 0%, #4e84cb 100%); padding: 35px; border-radius: 24px; font-family: 'Segoe UI', Roboto, Helvetica, Arial, sans-serif; box-shadow: 0 15px 35px rgba(76, 127, 199, 0.08); border: 1px solid rgba(255, 255, 255, 0.8); color: #334155;">
#     <div style="display: flex; justify-content: space-between; align-items: center; border-bottom: 2px solid #e2e8f0; padding-bottom: 25px; margin-bottom: 30px;">
#         <div>
#             <span style="background: linear-gradient(90deg, #3b82f6, #06b6d4); color: white; padding: 4px 14px; border-radius: 50px; font-size: 11px; font-weight: 700; text-transform: uppercase; letter-spacing: 1.5px; box-shadow: 0 4px 10px rgba(59, 130, 246, 0.25);">
#                 Analytics Web App
#             </span>
#             <h1 style="color: #1e293b; font-size: 34px; font-weight: 800; margin: 12px 0 6px 0; letter-spacing: -0.5px; background: linear-gradient(to right, #1e293b, #475569); -webkit-background-clip: text; -webkit-text-fill-color: transparent;">
#                 ❤️ Cardiovascular Health Insight Engine
#             </h1>
#             <p style="color: #64748b; font-size: 14px; margin: 0; font-weight: 500;">
#                 Advanced EDA & Multi-Model Predictive Framework
#             </p>
#         </div>
#             </div>
#         </div>
#     </div>
#     <div style="display: flex; gap: 16px; margin-bottom: 35px; flex-wrap: wrap;">
#         <div style="flex: 1; min-width: 140px; background: #ffffff; border: 1px solid #e2e8f0; padding: 16px 20px; border-radius: 16px; box-shadow: 0 4px 6px rgba(0,0,0,0.02);">
#             <div style="color: #94a3b8; font-size: 12px; font-weight: 700; text-transform: uppercase; letter-spacing: 0.5px;">Dataset</div>
#             <div style="color: #334155; font-size: 19px; font-weight: 700; margin-top: 6px;">Heart.csv</div>
#         </div>
#         <div style="flex: 1; min-width: 140px; background: #ffffff; border: 1px solid #e2e8f0; padding: 16px 20px; border-radius: 16px; box-shadow: 0 4px 6px rgba(0,0,0,0.02);">
#             <div style="color: #94a3b8; font-size: 12px; font-weight: 700; text-transform: uppercase; letter-spacing: 0.5px;">Features</div>
#             <div style="color: #3b82f6; font-size: 19px; font-weight: 700; margin-top: 6px;">14 Clinical</div>
#         </div>
#         <div style="flex: 1; min-width: 140px; background: #ffffff; border: 1px solid #e2e8f0; padding: 16px 20px; border-radius: 16px; box-shadow: 0 4px 6px rgba(0,0,0,0.02);">
#             <div style="color: #94a3b8; font-size: 12px; font-weight: 700; text-transform: uppercase; letter-spacing: 0.5px;">Target</div>
#             <div style="color: #ef4444; font-size: 19px; font-weight: 700; margin-top: 6px;">Classification</div>
#         </div>
#         <div style="flex: 1; min-width: 140px; background: #ffffff; border: 1px solid #e2e8f0; padding: 16px 20px; border-radius: 16px; box-shadow: 0 4px 6px rgba(0,0,0,0.02);">
#             <div style="color: #94a3b8; font-size: 12px; font-weight: 700; text-transform: uppercase; letter-spacing: 0.5px;">Author</div>
#             <div style="color: #06b6d4; font-size: 19px; font-weight: 700; margin-top: 6px; font-style: italic;">@YourName</div>
#         </div>
#     </div>
#     <h3 style="color: #475569; font-size: 15px; font-weight: 700; margin-bottom: 16px; text-transform: uppercase; letter-spacing: 1px;">
#         🎛️ Control Panel (Table of Contents)
#     </h3>
#     <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(220px, 1fr)); gap: 16px;">
#         <a href="#1" style="text-decoration: none; background: #ffffff; border: 1px solid #e2e8f0; padding: 18px; border-radius: 14px; box-shadow: 0 4px 10px rgba(0,0,0,0.01); display: block; transition: all 0.2s;">
#             <div style="color: #3b82f6; font-weight: 700; font-size: 15px;">01 // Setup</div>
#             <div style="color: #64748b; font-size: 13px; margin-top: 5px;">Environments & Ingestion</div>
#         </a>
#         <a href="#2" style="text-decoration: none; background: #ffffff; border: 1px solid #e2e8f0; padding: 18px; border-radius: 14px; box-shadow: 0 4px 10px rgba(0,0,0,0.01); display: block; transition: all 0.2s;">
#             <div style="color: #ec4899; font-weight: 700; font-size: 15px;">02 // Visualization</div>
#             <div style="color: #64748b; font-size: 13px; margin-top: 5px;">Deep EDA & Feature Correlation</div>
#         </a>
#         <a href="#3" style="text-decoration: none; background: #ffffff; border: 1px solid #e2e8f0; padding: 18px; border-radius: 14px; box-shadow: 0 4px 10px rgba(0,0,0,0.01); display: block; transition: all 0.2s;">
#             <div style="color: #06b6d4; font-weight: 700; font-size: 15px;">03 // Preprocessing</div>
#             <div style="color: #64748b; font-size: 13px; margin-top: 5px;">Engineering & Scaling Pipeline</div>
#         </a>
#         <a href="#4" style="text-decoration: none; background: #ffffff; border: 1px solid #e2e8f0; padding: 18px; border-radius: 14px; box-shadow: 0 4px 10px rgba(0,0,0,0.01); display: block; transition: all 0.2s;">
#             <div style="color: #10b981; font-weight: 700; font-size: 15px;">04 // Modeling</div>
#             <div style="color: #64748b; font-size: 13px; margin-top: 5px;">Training & Hyperparameter Tuning</div>
#         </a>
#     </div>
# </div>

# %% [markdown]
# <div id="1" style="background-color: #3b82f6; color: white; padding: 10px 20px; border-radius: 5px; margin-top: 30px; font-weight: bold; font-size: 18px;">
#     🔗 Step 1. Environment Setup & Data Loading
# </div>

# %% [markdown]
# <h2 style="
# background:#4F46E5;
# color:white;
# padding:12px 18px;
# border-radius:10px;
# ">
# 📊 1.3 Data Loading & Preprocessing
# </h2>

# %% [markdown]
# <div style="
# background:#ffffff;
# border:1px solid #EAEAEA;
# border-radius:14px;
# padding:18px;
# ">
#
# <span style="
# background:#5B4BFF;
# color:white;
# padding:6px 12px;
# border-radius:20px;
# font-size:14px;
# font-weight:bold;
# ">
# SECTION 1.3
# </span>
#
# <h2 style="margin-top:15px;color:#222;">
# 데이터 로드 & 전처리
# </h2>
#
# </div>

# %% [markdown]
# <div style="
#     border-left: 8px solid #6C63FF;
#     background-color:#F7F7FC;
#     padding:15px 20px;
#     border-radius:8px;
# ">
# <h2 style="margin:0;color:#333;">
# 1.3 데이터 로드 & 전처리
# </h2>
#
# <p style="margin-top:6px;color:#666;font-size:15px;">
# Load dataset and perform preprocessing.
# </p>
# </div>

# %% [markdown]
# ## <div style="background: linear-gradient(90deg, #5B4BFF, #7A5FFF);padding: 12px 18px;border-radius: 12px;color: white;font-size: 16px;
# font-weight: bold;box-shadow: 0 4px 8px rgba(0,0,0,0.15);">📂 1.3 데이터 로드 & 전처리</div>

# %% [markdown]
# <div style="
# background:linear-gradient(135deg,#5B4BFF,#8B5CF6);
# padding:28px;
# border-radius:18px;
# text-align:center;
# color:white;
# box-shadow:0 6px 18px rgba(91,75,255,.25);
# ">
#
# <h1 style="margin:0;font-size:42px;">📈 Beauty Company Stock Analysis</h1>
#
# <p style="margin-top:12px;font-size:18px;">
# Data Analysis · Time Series · Visualization
# </p>
#
# </div>

# %% [markdown]
# <div style="
# padding:10px;
# border-bottom:2px solid #E5E7EB;
# font-size:18px;
# font-weight:bold;
# color:#444;
# ">
#
# 📌 Missing Values
#
# </div>

# %% [markdown]
# <div style="
# background:#EEF2FF;
# border-left:6px solid #6366F1;
# padding:15px;
# border-radius:10px;
# ">
#
# 💡 <b>Insight</b>
#
# 데이터를 살펴보기 전에
# 결측치부터 확인한다.
#
# </div>

# %% [markdown]
# <div style="
# background:#FFF8E6;
# border-left:6px solid #F59E0B;
# padding:15px;
# border-radius:10px;
# ">
#
# 📝 <b>Note</b>
#
# rolling(window=30)은
# 최근 30일 기준이다.
#
# </div>

# %% [markdown]
# <div style="
# background:#FEF2F2;
# border-left:6px solid #EF4444;
# padding:15px;
# border-radius:10px;
# ">
#
# ⚠️ <b>Warning</b>
#
# Data Leakage가 발생하지 않도록
# 주의한다.

# %% [markdown]
# <div style="
# background:#ECFDF5;
# border-left:6px solid #10B981;
# padding:15px;
# border-radius:10px;
# ">
#
# ✅ <b>Result</b>
#
# Feature Engineering 완료
#
# </div>

# %% [markdown]
# <div style="
# background:#F9FAFB;
# padding:10px 16px;
# border-radius:10px;
# font-style:italic;
# color:#666;
# ">
#
# 🔍 이번 셀에서는 rolling volatility를 계산합니다.
#
# </div>

# %% [markdown]
# <hr style="height:3px;border:none;background:linear-gradient(to right,#5B4BFF,#A78BFA);border-radius:10px;">

# %% [markdown]
# ### <div style="border-left:6px solid #6C63FF;background:#F8F8FF;padding:12px 18px;border-radius:10px;font-size:80%;font-weight:600;">1.1 Load Dataset</div>

# %% [markdown]
# ## <div style="background:#ffffff;border:1px solid #EAEAEA;border-radius:14px;padding:10px;"><span style="background:#5B4BFF;color:white;padding:6px 12px;border-radius:20px;font-size:40%;font-weight:bold;">SECTION 1.3</span><h2 style="margin-top:10px;color: #222;font-size:100%;">데이터 로드 & 전처리</h2></div>

# %% [markdown]
# <div style="
# background:linear-gradient(135deg,#5B4BFF,#7C3AED);
# padding:18px 24px;
# border-radius:16px;
# color:white;
# box-shadow:0 6px 16px rgba(91,75,255,.18);
# ">
#
# <h2 style="margin:0;">📊 Chapter 1. Data Understanding</h2>
#
# </div>

# %% [markdown]
# ## <div style="background:#ffffff;border:1px solid #EAEAEA;border-radius:14px;padding:10px;"><span style="background:#5B4BFF;color:white;padding:6px 12px;border-radius:20px;font-size:40%;font-weight:bold;"> PROJECT | 002 </span><b><h2 style="margin-top:10px;color: #222;font-size:100%;">Healthcare Operations Analytics & Demand Forecasting (2023-2024)</h2></b></div>

# %% [markdown]
# <div style="
# background:white;
# border-radius:18px;
# padding:20px;
# border:1px solid #ECECEC;
# box-shadow:0px 4px 12px rgba(0,0,0,.05);
# ">
#
# <span style="
# background:#5B4BFF;
# color:white;
# padding:6px 14px;
# border-radius:50px;
# font-size:13px;
# font-weight:bold;
# ">
#
# CHAPTER 02
#
# </span>
#
# <h2 style="margin-top:16px;color:#222;">
# 📈 Exploratory Data Analysis
# </h2>
#
# </div>

# %% [markdown]
# <div style="
# border-left:8px solid #5B4BFF;
# padding-left:18px;
# ">
#
# <h2 style="margin-bottom:0;">
# 📂 3. Feature Engineering
# </h2>
#
# <p style="color:#777;margin-top:6px;">
# Create meaningful features from raw data.
# </p>
#
# </div>

# %% [markdown]
# <div style="
# background:rgba(255,255,255,.6);
# backdrop-filter:blur(8px);
# border:1px solid rgba(255,255,255,.3);
# border-radius:18px;
# padding:20px;
# box-shadow:0 8px 20px rgba(0,0,0,.08);
# ">
#
# <h2 style="margin:0;color:#444;">
# 🤖 Modeling
# </h2>
#
# </div>

# %% [markdown]
# <div style="
# padding:15px 0;
# border-bottom:3px solid #5B4BFF;
# ">
#
# <h2 style="
# margin:0;
# color:#333;
# ">
#
# 05. Model Evaluation
#
# </h2>
#
# </div>

# %% [markdown]
# ## <div style="border-left:8px solid #6C63FF;background:#F8F8FF;padding:12px 18px;border-radius:10px;font-size:30px;font-weight:600;"> 11 Load Dataset</div>

# %% [markdown]
# <div style="
# background:#F3F0FF;
# padding:18px;
# border-radius:14px;
# border-left:8px solid #6C63FF;
# ">
#
# <h2 style="
# margin:0;
# color:#4C1D95;
# ">
#
# 📊 Exploratory Data Analysis
#
# </h2>
#
# </div>

# %% [markdown]
# <div style="
# background:#1F2937;
# padding:20px;
# border-radius:16px;
# ">
#
# <h2 style="
# margin:0;
# color:white;
# ">
#
# ⚙️ Feature Engineering
#
# </h2>
#
# </div>

# %% [markdown]
# <div style="
# background:linear-gradient(90deg,#ffffff,#f8f9ff);
# padding:22px;
# border-radius:18px;
# border:2px solid #E8E8FF;
# ">
#
# <div style="
# font-size:13px;
# letter-spacing:2px;
# color:#7C3AED;
# font-weight:bold;
# ">
#
# CHAPTER 03
#
# </div>
#
# <h2 style="
# margin-top:8px;
# margin-bottom:0;
# color:#222;
# ">
#
# 📊 Exploratory Data Analysis
#
# </h2>
#
# </div>
